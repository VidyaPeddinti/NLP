# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re

# Load NLTK resources
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Vidya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to preprocess text
def preprocess_text(text):
    # Initialize stop words
    stop_words = set(stopwords.words('english'))
    
    # Convert to lowercase
    text = text.lower()
    # Remove non-alphanumeric characters and replace with space
    text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)
    # Tokenize text
    words = text.split()
    # Remove stop words
    words = [word for word in words if word not in stop_words]
    # Stemming
    stemmer = SnowballStemmer("english")
    words = [stemmer.stem(word) for word in words]
    # Join the words back into a string
    text = ' '.join(words)
    return text

file_path = r"C:\Users\Vidya\Desktop\vidya\text.csv"
data = pd.read_csv(file_path)


# Preprocess the text
data['text'] = data['text'].apply(preprocess_text)

# Assuming your data is in the format provided
tweets = data['text']
labels = data['label']

# %%
data.head()
# Out:
#    Unnamed: 0                                               text  label
# 0           0                   feel realli helpless heavi heart      4
# 1           1  ive enjoy abl slouch relax unwind frank need l...      0
# 2           2               gave internship dmrg feel distraught      4
# 3           3                                dont know feel lost      0
# 4           4  kindergarten teacher thorough weari job taken ...      4

# %%
data.shape
# Out:
# (416809, 3)

# %%
# Preprocess the data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(tweets)
sequences = tokenizer.texts_to_sequences(tweets)
max_sequence_length = max([len(x) for x in sequences])
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length)

# Encode the labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)

# %%
sequences
# Out:
# [[1, 6, 213, 1257, 133],
#  [21,
#   169,
#   114,
#   12246,
#   267,
#   4939,
#   1651,
#   27,
#   81,
#   67,
#   53,
#   82,
#   2634,
#   11415,
#   136,
#   29,
#   60,
#   1,
#   26,
#   810,
#   51,
#   6,
#   38,
#   16],
#  [755, 4248, 26262, 1, 998],
#  [28, 4, 1, 177],
#  [4524,
#   849,
#   1908,
#   2681,
#   226,
#   626,
#   856,
#   3741,
#   1107,
#   358,
#   964,
#   67,
#   10,
#   847,
#   31,
#   739,
#   1634],
#  [282, 1, 65, 647],
#  [15, 12, 6457, 15, 361, 84, 264, 1685, 227, 1, 2, 479, 117, 992],
#  [199, 101, 1, 528, 141, 654, 2845, 244, 23, 99],
#  [3, 954, 46, 7, 617, 1, 166],
#  [19, 379, 469, 94, 1, 543],
#  [35, 398, 55, 5, 537, 49, 781, 1167, 1, 250, 13, 695, 834, 2189, 173],
#  [3, 1, 13, 2, 556, 1203, 1918, 13, 19462],
#  [1785, 1609, 3, 1, 665, 59, 15],
#  [1,
#   2,
#   2062,
#   1839,
#   538,
#   1546,
#   11,
#   10739,
#   48,
#   321,
#   1442,
#   727,
#   10739,
#   3305,
#   722,
#   564,
#   538,
#   1501,
#   3226,
#   1240,
#   577,
#   1224],
#  [1, 4872, 3264, 515, 207, 4, 92, 131, 154, 276, 3374],
#  [134, 4525, 181, 1340, 24, 46, 97, 104, 327, 1, 27, 46, 97, 56],
#  [1, 767],
#  [129, 146, 56, 1, 194, 529, 174, 54],
#  [1, 259, 977, 136],
#  [7904, 2652, 4298, 1, 197, 4161, 655, 7905, 836, 891, 517, 265, 75, 1596],
#  [27, 1, 423, 42, 2032, 865, 592, 713, 6795, 465, 412],
#  [1, 22, 1146, 219, 1295, 932, 4, 79, 622],
#  [46, 1186, 1, 108, 498, 1125, 1, 24, 218, 990, 1, 461, 24, 2, 4332, 24, 96],
#  [1, 850, 7, 177, 459, 9226, 300],
#  [15,
#   494,
#   17,
#   156,
#   1262,
#   171,
#   2369,
#   33,
#   38,
#   102,
#   458,
#   106,
#   106,
#   8,
#   171,
#   11,
#   1,
#   20,
#   360,
#   1,
#   2,
#   106,
#   1743,
#   14,
#   28,
#   4],
#  [1, 2, 251, 844, 101, 496, 844],
#  [1, 2, 80, 5, 25, 47],
#  [114, 1712, 271, 1, 231, 649, 7205, 605, 50, 1949],
#  [],
#  [283, 944, 231, 183, 1, 215],
#  [172, 1, 3, 6, 5, 615],
#  [27, 192, 6, 2442, 8, 551, 124, 1, 42, 505, 67],
#  [1, 647, 942, 139, 5, 1316, 879],
#  [1, 475, 22, 41, 137],
#  [75, 447, 32, 6, 1, 411, 190, 13, 16, 3, 73, 15, 9],
#  [220,
#   4162,
#   1645,
#   40,
#   16522,
#   544,
#   207,
#   45,
#   412,
#   912,
#   337,
#   45,
#   191,
#   7,
#   11,
#   63,
#   270,
#   1,
#   360,
#   62,
#   2,
#   113,
#   9],
#  [279, 297, 9, 718, 1, 13, 585, 8, 115, 89, 371],
#  [220, 1, 385, 431, 24],
#  [425, 1, 25, 43, 556, 330, 635, 206, 16, 1433],
#  [103, 51, 1141, 17],
#  [1961,
#   1,
#   234,
#   140,
#   1713,
#   66,
#   332,
#   140,
#   331,
#   1652,
#   1019,
#   5159,
#   4125,
#   1061,
#   1539,
#   331,
#   26263,
#   10740],
#  [1, 776, 462, 31, 2666, 10160, 485, 898],
#  [12, 248, 8, 530, 2707, 479, 23, 8, 965, 1, 626, 97, 11],
#  [488, 1, 584],
#  [1, 24, 263, 665, 2635],
#  [1, 908, 62, 1214, 396],
#  [345, 160, 262, 8, 52, 222, 33, 1, 19463, 574, 6, 562, 12, 34, 4812, 94],
#  [1, 26, 519, 3330, 689, 197],
#  [99, 1, 1438, 12247, 678, 269],
#  [1, 641, 33, 328, 1020, 491, 362, 1028, 587, 14627, 1253, 712],
#  [239, 238, 277, 1, 55, 482],
#  [15, 10, 155, 113, 133, 1, 11, 4424, 109, 7],
#  [1, 621, 108, 114, 104, 26264, 106, 11416, 1193],
#  [1, 22, 447],
#  [1, 998, 121, 3500, 69, 7, 781, 787, 61],
#  [1786, 22, 72, 1, 185],
#  [191, 1, 2, 341, 1, 121, 213],
#  [66, 65, 382, 29, 6, 6, 1267, 2, 54, 1, 375, 45, 347],
#  [30, 3, 35, 207, 1, 2, 633, 84, 7, 17, 18, 113, 137, 206, 2518, 1474],
#  [1, 700, 211, 112, 1244, 587, 448, 100],
#  [1, 62, 75, 899],
#  [129, 1, 294, 153, 2406, 46, 812],
#  [112,
#   1076,
#   17,
#   23,
#   1,
#   112,
#   1076,
#   558,
#   43,
#   40,
#   17,
#   1610,
#   112,
#   44,
#   825,
#   1597,
#   9687,
#   43,
#   49,
#   1610],
#  [51, 1, 121, 215, 39, 68],
#  [3, 1, 13, 92, 654, 750, 59, 812, 144, 654, 1663, 3, 387, 20, 589],
#  [1, 280, 275, 81, 123, 2552, 1470, 2120, 232, 3742, 826, 4582],
#  [352, 22, 1, 415],
#  [1, 164, 219, 447, 495, 513, 251, 96],
#  [4, 1, 474],
#  [4, 3, 9, 278, 21, 258, 2069, 45, 199, 120, 82, 1, 392],
#  [1, 26265, 744],
#  [1, 194, 303, 14, 2345, 5, 167, 178, 549, 143, 194, 28, 8, 41, 12],
#  [3,
#   583,
#   805,
#   6796,
#   141,
#   1371,
#   836,
#   3531,
#   480,
#   2138,
#   3375,
#   300,
#   24,
#   406,
#   1016,
#   2489,
#   915,
#   1,
#   416,
#   176],
#  [120, 64, 7, 7, 3, 1, 209, 297, 106, 3, 160],
#  [19, 26, 6627, 287, 1, 95, 25, 545, 127, 1539, 992, 106],
#  [1, 557, 211, 117, 130, 180, 408, 185, 20],
#  [1, 1776, 553, 1234, 743, 478, 598, 8, 31],
#  [1, 576, 63, 894, 552],
#  [107, 2145, 43, 31, 3060, 356, 1, 233, 138, 1704, 407, 645, 440, 6],
#  [114, 379, 531, 5833, 1, 498, 20, 198, 235, 16, 130, 1102],
#  [1, 250, 463, 94, 871],
#  [228, 170, 529],
#  [99, 1, 407, 368, 1204, 4684, 1081, 983],
#  [12, 66, 29, 1, 505],
#  [144, 38, 18, 67, 198, 800, 1, 2, 48, 81, 24, 48, 150],
#  [3, 1365, 330, 1, 408, 519],
#  [1, 2407, 284, 25, 2407, 1, 267, 107, 1, 267, 1011, 1247, 463, 49],
#  [1, 118, 802, 6458, 41],
#  [3, 19, 3, 1, 1109, 136],
#  [1, 6, 135],
#  [10, 184, 233, 137, 10, 162, 44, 1, 271, 135],
#  [1, 75, 75, 415, 321, 212, 688, 18, 18, 743],
#  [2779, 1, 897, 148, 669, 249],
#  [3, 1066, 29, 1, 319],
#  [1, 185, 1372, 4486, 6187, 4016, 651],
#  [1, 2, 345, 105, 644, 13, 1574, 7, 272, 267, 408],
#  [1, 213, 7419, 429],
#  [3981, 71, 71, 45, 1, 1144, 503, 108],
#  [1, 2, 9227, 138, 6, 102, 910, 71, 14, 70, 19, 61, 2224, 71],
#  [1, 2, 2215, 100, 133, 26, 26, 280, 504, 249, 10741],
#  [5, 1, 5240, 272, 1198, 39],
#  [1, 259, 74, 23, 1, 20, 259, 20, 158],
#  [48,
#   178,
#   86,
#   20,
#   55,
#   3,
#   145,
#   1,
#   166,
#   319,
#   1,
#   8497,
#   19,
#   1062,
#   104,
#   30,
#   3102,
#   158],
#  [1583, 3247, 19464, 1209, 34, 955, 1354, 873, 1, 541],
#  [1,
#   69,
#   158,
#   627,
#   489,
#   227,
#   5,
#   1622,
#   1696,
#   1335,
#   26266,
#   550,
#   387,
#   260,
#   2408,
#   39],
#  [1, 13, 866, 20, 5620, 12248, 15, 2358, 18, 5160],
#  [1,
#   280,
#   186,
#   50,
#   1275,
#   166,
#   325,
#   2,
#   1375,
#   8498,
#   1210,
#   870,
#   6188,
#   6797,
#   13227,
#   854],
#  [3, 1, 11417, 29, 26267, 19465, 6, 432, 13228],
#  [159, 759, 1, 508, 563],
#  [1, 92, 878],
#  [341, 21, 3201, 1686, 1, 467],
#  [1, 360, 441, 17, 86, 16],
#  [2,
#   317,
#   1037,
#   2,
#   175,
#   1,
#   2,
#   32,
#   285,
#   33,
#   1071,
#   49,
#   844,
#   675,
#   892,
#   892,
#   94,
#   11,
#   2359,
#   27,
#   4017],
#  [1, 1254, 27, 178, 404, 644, 36, 315, 4526, 2, 2949],
#  [1, 824, 156],
#  [1, 34, 2, 17, 202, 19, 677, 22, 802, 1768, 2995],
#  [6,
#   11,
#   72,
#   2263,
#   1,
#   852,
#   934,
#   1206,
#   1,
#   69,
#   677,
#   158,
#   30,
#   44,
#   88,
#   125,
#   1206,
#   2535,
#   959,
#   126,
#   1616,
#   44,
#   34,
#   36,
#   461,
#   95,
#   96],
#  [21, 1, 385, 213],
#  [1, 2, 21, 269, 87],
#  [1, 403, 28, 4, 270, 14, 347],
#  [15, 232, 1, 202, 444, 32, 579, 516, 319],
#  [1, 26, 522, 83, 211, 188, 26268, 2580],
#  [1, 71, 419, 842, 171, 104],
#  [241, 49, 22, 219, 1, 316],
#  [7, 191, 78, 776, 60, 803, 448, 100, 879, 2581],
#  [3, 77, 1, 385, 226, 266],
#  [27,
#   168,
#   20,
#   1176,
#   107,
#   152,
#   132,
#   146,
#   40,
#   94,
#   1,
#   915,
#   866,
#   451,
#   94,
#   706,
#   692,
#   40,
#   256,
#   821],
#  [1, 26, 580, 177, 105],
#  [755, 685, 397, 1, 1012, 63, 358, 4425, 3351, 282, 494, 134, 448, 947],
#  [1, 42, 580, 2004, 180, 531, 2346, 19, 760],
#  [1, 509, 43, 818],
#  [1, 333, 3],
#  [21, 1, 536, 71, 146, 53, 536],
#  [3, 103, 456, 210, 1836, 490, 182, 1301, 1215, 36, 2021, 253, 1, 63, 785, 11],
#  [1, 6, 894, 234, 1107, 73, 2070, 399, 7],
#  [290, 155, 1, 4940, 742, 14, 254, 14, 30, 528],
#  [1, 63, 25, 2312, 3030, 28, 5, 167],
#  [39, 1, 402, 627, 20, 485, 403],
#  [1, 26, 2653],
#  [1, 297, 37, 1510, 1217, 6798, 587, 1359, 673, 1372, 5, 3456, 3774],
#  [52, 1, 162, 812, 471, 106, 24],
#  [4, 17, 156, 4204, 3743, 3137, 3901, 3901, 66, 192, 34, 1147, 1, 616],
#  [417,
#   5161,
#   12,
#   417,
#   145,
#   5161,
#   1017,
#   13,
#   124,
#   35,
#   264,
#   5161,
#   75,
#   1,
#   6,
#   267,
#   68,
#   18],
#  [1, 2, 3, 403, 49],
#  [29, 638, 100, 122, 1, 320, 2654, 4085, 3352, 7906],
#  [1, 877, 5, 518, 4941, 80, 354, 878],
#  [35, 635, 1, 2, 555, 895, 4, 5, 288, 36, 1102],
#  [1, 291, 114, 847, 164, 1617, 196, 32, 51, 168],
#  [1, 230, 48, 12, 79, 252, 6, 1018, 314, 5, 3202, 189, 12, 12, 12],
#  [21, 43, 36, 7206, 21, 1, 535],
#  [44, 108, 212, 32, 39, 59, 1, 566, 7, 102],
#  [1, 443, 91, 2, 3, 38, 84, 222, 37, 91, 20, 112],
#  [15, 1, 640, 467],
#  [3, 1, 26, 88, 659, 1278, 13229, 4942],
#  [1, 2, 664, 165, 150, 112, 126],
#  [1, 420],
#  [3, 1, 26, 585],
#  [845, 1, 166, 1, 105, 685, 1772, 154, 1144, 32, 1805, 1103],
#  [1316, 1, 13, 230, 1840],
#  [1777, 1, 230, 300, 173, 503, 38, 143, 223, 685, 350, 352, 104, 729, 12],
#  [10, 113, 4, 20, 1, 621, 471, 41, 24, 218, 532, 494, 10],
#  [1, 275, 547, 783, 1848, 2, 49, 1176, 293, 658, 400, 5417, 820],
#  [82, 1, 42, 767, 581],
#  [352, 1, 785, 113, 613, 9, 3, 6, 42, 3573, 149, 206, 170, 16],
#  [1, 358, 14, 1865, 45, 412, 38, 1787],
#  [15, 232, 20, 1081, 837, 1, 15, 93],
#  [1, 2, 151, 145, 134, 679, 2070, 35, 5949],
#  [12, 147, 1217, 3775, 678, 501, 110, 29, 1, 2, 31, 318, 306, 12249],
#  [971, 74, 361, 234, 346, 46, 100, 138, 112, 358, 1, 385, 79],
#  [1, 2, 36, 304],
#  [341, 1, 1671, 155, 868, 289, 355],
#  [188, 53, 218, 27, 3718, 101, 102, 1, 323, 2, 132, 2827, 113, 4, 3],
#  [21,
#   1,
#   19466,
#   186,
#   386,
#   67,
#   215,
#   1038,
#   14628,
#   206,
#   196,
#   936,
#   185,
#   1592,
#   106,
#   859],
#  [1, 305, 26269, 1668, 71, 156, 1402, 17, 835, 68, 628],
#  [1, 57, 2010, 68, 1854, 3, 290],
#  [4,
#   1021,
#   3061,
#   372,
#   133,
#   1810,
#   630,
#   2106,
#   138,
#   1271,
#   2752,
#   209,
#   3156,
#   2567,
#   1271,
#   455,
#   788,
#   1099,
#   704,
#   469,
#   1293,
#   4163,
#   189,
#   7,
#   379,
#   1271,
#   2264,
#   1,
#   186],
#  [341, 1, 74, 369, 1],
#  [239, 383, 32, 1, 185, 86, 18, 6, 2, 2593, 225, 106],
#  [1, 670, 611, 31, 241, 442, 14, 197, 1097, 975],
#  [66, 161, 1, 498],
#  [1, 526, 115, 89, 26270],
#  [1, 57, 193, 5081, 208, 179, 4943, 1017, 36, 2179, 138, 1006, 1855, 36, 24],
#  [44, 583, 80, 1, 270, 201, 750, 1, 23, 270, 92, 270],
#  [11,
#   891,
#   917,
#   11,
#   2331,
#   705,
#   488,
#   1,
#   442,
#   891,
#   2331,
#   20,
#   55,
#   2682,
#   283,
#   3691,
#   727,
#   463,
#   49,
#   59,
#   96],
#  [1, 609, 1962, 315, 2423, 1491, 348, 39, 125],
#  [140, 242, 1, 75, 199, 1736, 215, 7],
#  [21, 1, 166],
#  [1, 426, 276, 195, 7, 206, 62, 300],
#  [1, 103, 551, 31, 113, 146, 30, 31, 1012, 103, 773],
#  [1, 2, 515, 5, 8832, 387, 81, 531, 45],
#  [1, 2, 202, 3248, 802, 793, 846, 2, 994, 2490, 1238, 16, 26],
#  [2,
#   281,
#   18,
#   9,
#   126,
#   724,
#   8499,
#   2450,
#   1488,
#   19467,
#   108,
#   1163,
#   325,
#   3,
#   1,
#   209,
#   446,
#   9,
#   13230,
#   1106,
#   9228,
#   26271,
#   13,
#   756],
#  [47, 777, 2454, 24, 551, 60, 797, 1, 92, 1030, 158],
#  [1, 425, 492, 4944],
#  [3, 1, 1280, 48, 130, 5, 16, 45, 71, 14],
#  [4, 697, 1, 585, 188, 100, 233, 122, 719, 262, 346, 133],
#  [86, 62, 2190, 29, 1, 23, 52],
#  [4, 559, 2086, 762, 541, 1, 26, 645, 464, 818, 6, 520, 5718, 2740, 762],
#  [33, 26272, 1, 416, 413, 416, 502, 101, 6, 659, 1759, 422, 176],
#  [309, 116, 1, 443, 20, 45, 235, 282],
#  [64, 34, 1, 108, 466, 1048, 71, 2, 2185, 280, 266],
#  [1, 2, 22, 579, 13, 278],
#  [1, 466, 152, 656, 157, 382, 1483, 19468, 844, 16, 14, 11, 72],
#  [368, 1, 545, 3400],
#  [3, 179, 2478, 235, 686, 973, 143, 18, 3, 1, 1112, 1402],
#  [31, 62, 2225, 212, 1245, 1, 219, 774, 1516, 109, 96, 4583],
#  [334, 262, 40, 1, 19469, 585, 410, 411, 7420],
#  [99, 1, 292, 368, 313, 805, 263],
#  [3, 1, 119],
#  [1, 205, 106, 2468, 1227, 690],
#  [1, 327, 84, 1475],
#  [1, 960, 448, 4, 76, 409, 1180, 354],
#  [1, 231, 145],
#  [15, 2, 1, 11, 852, 77, 157, 203, 1],
#  [1,
#   119,
#   1478,
#   147,
#   1225,
#   46,
#   140,
#   1,
#   92,
#   101,
#   91,
#   27,
#   13,
#   26,
#   2636,
#   5,
#   126,
#   9,
#   50,
#   3,
#   9,
#   86,
#   252,
#   693,
#   19470],
#  [413, 1, 619],
#  [58, 1, 19471, 993],
#  [1, 55, 107, 3719, 563, 1482, 452, 329, 452, 266, 1063, 168, 9, 329, 1218],
#  [12,
#   99,
#   51,
#   321,
#   159,
#   1854,
#   4164,
#   85,
#   61,
#   248,
#   1,
#   121,
#   213,
#   1211,
#   58,
#   12250,
#   1302,
#   4,
#   86],
#  [1, 13, 456, 1255, 795, 127, 1679, 4749, 750, 2976, 281, 7],
#  [769, 208, 60, 2568, 48, 40, 1, 15, 562, 3609, 43, 157, 464, 13, 16],
#  [1216, 1, 13, 259],
#  [131, 46, 779, 818, 1, 505],
#  [1, 116, 1, 595, 351, 57],
#  [3, 1258, 19, 1, 22, 498, 878, 1, 103, 1902, 7659],
#  [3, 1, 42, 437, 16, 191, 2042, 209, 124, 3828, 1307, 1164, 4873],
#  [725,
#   728,
#   636,
#   72,
#   794,
#   33,
#   102,
#   152,
#   728,
#   919,
#   16,
#   131,
#   35,
#   72,
#   763,
#   16,
#   145,
#   1263,
#   33,
#   1,
#   566,
#   46,
#   117],
#  [1, 13, 908, 110, 1349, 16],
#  [1, 59, 9, 485, 332],
#  [1,
#   27,
#   281,
#   409,
#   714,
#   1690,
#   433,
#   872,
#   1011,
#   165,
#   3138,
#   2727,
#   4249,
#   1253,
#   1314,
#   253,
#   145,
#   816,
#   913,
#   1011,
#   3532,
#   264],
#  [1, 775, 215, 76, 613, 633, 71, 90, 16, 983, 901],
#  [2887, 16523, 232, 9, 5, 3720, 34, 341, 1, 121, 403],
#  [4, 19, 1, 286, 12, 32, 160, 748],
#  [52, 1, 365, 17, 16, 263, 834, 268, 8, 1120],
#  [6, 52, 1, 5, 310, 63, 869, 11],
#  [172, 1, 253, 83],
#  [77, 1, 960],
#  [3286,
#   10161,
#   16524,
#   21,
#   39,
#   10,
#   9,
#   25,
#   2,
#   10162,
#   770,
#   2253,
#   3,
#   906,
#   1837,
#   14,
#   1,
#   545,
#   2138,
#   1,
#   551,
#   236,
#   3863,
#   57],
#  [1, 428, 7],
#  [70,
#   2,
#   347,
#   44,
#   659,
#   764,
#   764,
#   42,
#   22,
#   109,
#   17,
#   183,
#   3501,
#   1,
#   1112,
#   5082,
#   206,
#   261,
#   95,
#   811,
#   2107],
#  [46,
#   185,
#   3982,
#   45,
#   70,
#   166,
#   624,
#   4426,
#   1539,
#   16,
#   435,
#   4,
#   39,
#   551,
#   127,
#   1,
#   1704,
#   448,
#   240,
#   137,
#   1704,
#   38,
#   126],
#  [1, 13, 163, 69, 7, 30, 2074, 251, 24],
#  [48, 605, 1, 48, 86, 144, 177, 2108, 48, 87, 544, 1412, 265],
#  [1421,
#   1,
#   118,
#   1027,
#   1194,
#   2594,
#   26273,
#   308,
#   12251,
#   4204,
#   779,
#   3044,
#   800,
#   154,
#   80,
#   801,
#   2237,
#   22,
#   4427,
#   588,
#   5162,
#   241],
#  [1, 26, 1139, 7],
#  [3, 36, 1, 543, 3, 73, 139],
#  [1, 42, 426, 212, 18, 26274, 888, 3401, 194],
#  [990, 859, 1464, 107, 189, 2226, 909, 171, 1, 354],
#  [345, 3176, 45, 234, 1, 2, 17, 6, 10, 42, 447, 84],
#  [4626, 552, 1, 213, 1064, 764, 2254, 529, 769, 178, 31, 848, 1439],
#  [1,
#   369,
#   14,
#   930,
#   146,
#   23,
#   694,
#   795,
#   188,
#   79,
#   241,
#   1788,
#   1791,
#   146,
#   1903,
#   5950],
#  [34, 1, 316, 4, 58],
#  [1, 400, 141, 1609, 3480, 29, 1553],
#  [1, 193],
#  [1,
#   363,
#   1,
#   167,
#   1,
#   5719,
#   177,
#   308,
#   1,
#   2370,
#   47,
#   8833,
#   113,
#   29,
#   113,
#   29,
#   113,
#   29],
#  [1, 255, 6, 129],
#  [1, 499, 161, 31, 49, 24, 8, 499],
#  [21, 19472, 1, 258, 118, 2, 1826, 1314, 59, 11418],
#  [1, 2, 70, 898, 35, 168, 1981, 607, 296, 49],
#  [120, 1, 580],
#  [1, 2519, 640, 157, 203, 398, 117, 70, 300, 85, 676, 212, 26275, 40],
#  [1, 351, 596],
#  [4, 1, 458, 2265, 127, 137, 1206, 954, 607, 34, 173, 836, 192, 3481, 992],
#  [3, 19, 11, 3, 188, 528, 325, 1, 543, 20, 5, 586, 2569, 1930, 1914, 2536],
#  [1, 60, 152, 700, 432],
#  [1, 783, 580, 41],
#  [1, 2, 66, 84, 219, 30, 17, 2, 2227, 146],
#  [1, 434, 228, 493, 86, 33, 174, 23],
#  [461, 152, 110, 1, 250, 152, 146, 274, 76, 1777, 978, 36, 46, 1777, 25, 2265],
#  [99, 45, 412, 108, 15, 1, 4749, 555, 7907, 2043, 754, 1681, 2780, 1915, 1087],
#  [1, 768, 214, 2683, 3123, 16525],
#  [28, 240, 1, 1276, 834, 25, 5, 92, 1308, 1021],
#  [1,
#   13,
#   486,
#   33,
#   745,
#   860,
#   967,
#   6628,
#   4384,
#   378,
#   1443,
#   1366,
#   23,
#   461,
#   294,
#   10742,
#   27,
#   19473,
#   1890,
#   252,
#   1068,
#   3902,
#   3088,
#   2791],
#  [21, 439, 23, 22, 7, 1, 138, 175, 3, 595, 122, 312],
#  [3, 1, 594, 19],
#  [1, 119, 9, 521, 114, 966, 18, 1107],
#  [1, 580, 69, 7, 3665, 951, 1471, 310, 1, 2, 6, 379, 106],
#  [3, 1, 2, 181, 386, 18, 9, 602, 924, 10163, 124, 54, 5, 281, 22, 7, 591],
#  [1, 236, 838],
#  [142, 1, 2, 813, 788, 48, 20, 282, 494, 1248, 112, 227, 1, 801, 9, 41],
#  [439, 45, 140, 53, 1268, 1, 406, 449, 1, 930, 1, 568, 1, 259],
#  [330, 1, 269, 31, 1841],
#  [1, 458, 50],
#  [220, 1792, 215, 1973, 1, 57],
#  [1, 515, 16, 6, 29, 125],
#  [21, 66, 9, 351, 1141, 914, 268, 1, 119],
#  [1, 158, 641, 7, 19474, 1259],
#  [1, 63, 208, 1317, 53, 595, 12, 63, 203, 35, 128],
#  [1489, 36, 2021, 1, 964, 252, 139, 1237, 252],
#  [1, 177, 119, 13, 7421],
#  [227,
#   30,
#   1,
#   13,
#   645,
#   2498,
#   133,
#   2301,
#   1560,
#   722,
#   439,
#   65,
#   1596,
#   829,
#   7,
#   65,
#   156,
#   829,
#   409,
#   43,
#   175,
#   12,
#   602,
#   3305,
#   794,
#   325,
#   2290,
#   3744,
#   111],
#  [1, 132, 40, 517, 8, 75, 447, 49, 3, 132, 40, 48, 427, 1],
#  [5,
#   68,
#   1144,
#   441,
#   2087,
#   52,
#   1,
#   536,
#   247,
#   777,
#   4052,
#   175,
#   1245,
#   14629,
#   806,
#   4487,
#   56,
#   2759,
#   244,
#   3156,
#   1763],
#  [27, 87, 14, 3, 9, 1, 2, 3, 6189, 103, 379, 472, 179, 1341],
#  [1, 83, 111, 19475, 6067],
#  [1, 26, 473],
#  [1, 2, 10, 168, 115, 89, 150, 19476],
#  [1, 929, 94, 1636, 209, 1133],
#  [1, 2, 748, 1, 23, 2, 748, 491],
#  [1, 4, 634, 1422, 6, 6, 10, 31, 92, 1422, 28, 1017, 251],
#  [141, 289, 225, 7, 1, 13, 505],
#  [85, 1, 647, 768, 2121],
#  [1, 450, 409, 138],
#  [1, 365, 391],
#  [366, 1, 118, 1646, 2371, 212, 18],
#  [10,
#   534,
#   10,
#   139,
#   1,
#   313,
#   93,
#   288,
#   94,
#   1075,
#   93,
#   20,
#   1458,
#   2024,
#   23,
#   445,
#   2888,
#   8834,
#   817,
#   27],
#  [1, 167, 1, 167, 33, 3983, 33, 3983],
#  [20, 30, 932, 25, 94, 1, 470],
#  [180,
#   33,
#   780,
#   262,
#   12252,
#   26276,
#   7422,
#   3062,
#   1,
#   7423,
#   1196,
#   7207,
#   227,
#   2595,
#   2139,
#   313,
#   10164,
#   132],
#  [1, 886],
#  [12, 242, 38, 1304, 131, 1, 8165, 228, 16, 24, 28, 1, 744],
#  [111, 111, 1, 474, 171, 34, 614, 714, 1682],
#  [1, 360, 237, 495, 1406, 43, 337, 326],
#  [341, 1129, 762, 15, 9, 77, 7, 820, 19, 171, 1, 353],
#  [3, 23, 979, 48, 982, 1, 3, 584],
#  [19, 1, 405, 91],
#  [12, 1511, 1310, 25, 268, 22, 16526, 1, 339, 357, 1113, 269, 155, 332],
#  [91, 1, 354],
#  [602, 1881, 1, 38],
#  [9, 64, 17, 3157, 1, 1539, 1639, 483, 2820, 204, 17, 1647],
#  [12, 1, 831, 314, 68, 249],
#  [3, 1, 426, 379, 1977, 469, 379],
#  [3, 29, 1, 315, 962, 9, 125],
#  [1130, 241, 1, 2, 484, 83, 1130, 1, 2, 484, 146, 14],
#  [142, 202, 5, 1, 2, 1709, 2693, 93, 79, 1253, 1914, 2596, 93, 25],
#  [6, 1, 291],
#  [3, 19, 1, 13, 276],
#  [44, 99, 1, 2, 11, 308, 3249, 296, 57, 1640, 736, 256, 391],
#  [1, 72, 752, 1624, 754],
#  [64, 9229, 5, 661, 1304, 4250, 1, 457, 378, 64, 942, 302],
#  [1, 61, 658, 820],
#  [1, 2525, 485, 1318, 7],
#  [178, 206, 16, 1, 573],
#  [1, 478, 9, 165, 3287, 17, 41],
#  [1, 26, 960, 12, 3574, 300, 2, 8, 714],
#  [1,
#   418,
#   1346,
#   312,
#   1167,
#   254,
#   1625,
#   187,
#   4428,
#   7908,
#   629,
#   6459,
#   862,
#   326,
#   438,
#   148,
#   6068,
#   3745],
#  [1, 292, 1399],
#  [224, 9, 1, 13, 26, 255, 2499, 224, 11419],
#  [1, 2505],
#  [1, 6, 601, 26, 3376, 239, 32, 36, 6629, 170],
#  [5,
#   9,
#   2264,
#   69,
#   18,
#   740,
#   317,
#   77,
#   14,
#   772,
#   91,
#   1,
#   449,
#   137,
#   10,
#   533,
#   82,
#   138,
#   1459,
#   2332,
#   1611,
#   2,
#   3177,
#   45,
#   1262,
#   162,
#   17,
#   40],
#  [1, 752, 286, 637],
#  [239, 19, 1, 68],
#  [254, 37, 9, 8500, 1554, 70, 1, 13, 655],
#  [1, 11, 1264, 938, 521, 819, 1858, 2, 1277],
#  [1,
#   1793,
#   1001,
#   83,
#   338,
#   228,
#   264,
#   1362,
#   1,
#   216,
#   1793,
#   31,
#   25,
#   76,
#   115,
#   89,
#   4584],
#  [1, 24, 1651, 13, 304],
#  [1, 131, 47, 849, 3123, 31, 7208],
#  [1, 249, 115, 89, 26277],
#  [1454, 9230, 528, 7424, 1051, 1123, 118, 1, 65, 648],
#  [1, 1052, 1350, 1575, 139, 517, 28, 1, 1700],
#  [2, 1, 483, 814, 686, 65, 433],
#  [74, 2255, 2063, 1467, 1, 545, 11, 68],
#  [1, 102, 115, 89, 26278],
#  [1228, 977, 193, 1, 197, 2, 1602, 217, 825, 498, 197, 193, 1434, 825],
#  [3, 1, 166, 41, 28, 4, 116, 25, 203],
#  [3, 12, 1, 297, 922, 1563],
#  [180, 1, 8835, 3013, 2127, 782, 2384, 158, 4, 65, 1516],
#  [201, 1, 265, 227, 363, 57, 97, 703],
#  [1, 2, 248, 15, 101, 47, 843, 768, 2321, 32, 232, 153, 212],
#  [1, 5, 428, 1176, 86, 347, 2, 8, 116, 1, 2, 76],
#  [134, 1, 2, 3, 225, 1217, 849, 228, 27, 104, 578, 156, 29, 110, 45, 412],
#  [58, 1, 1130, 333, 242, 81, 350, 1082, 2570, 101],
#  [52, 105, 121, 1, 225, 14, 53, 11, 455, 1741],
#  [1, 236, 297, 64, 136, 125, 143, 156, 3, 128, 935, 719, 3, 57],
#  [539,
#   32,
#   232,
#   95,
#   2,
#   95,
#   1858,
#   455,
#   539,
#   6,
#   1,
#   144,
#   1168,
#   289,
#   1937,
#   228,
#   11],
#  [11, 1, 47],
#  [1, 77, 541, 6069, 24, 1079, 1460, 3, 317, 316, 106],
#  [4,
#   158,
#   22,
#   723,
#   76,
#   6799,
#   158,
#   6800,
#   8,
#   1,
#   111,
#   843,
#   5325,
#   74,
#   1575,
#   65,
#   1651,
#   66,
#   426],
#  [598, 8, 1157, 2423, 1247, 8, 1, 2, 1039, 1267, 537],
#  [488, 1, 515, 122, 74, 319, 2, 3061, 365, 223],
#  [368, 40, 1, 256, 508, 149],
#  [3, 1, 595, 28, 4, 920],
#  [1, 1027, 10, 264, 78, 159, 3829, 224, 1495],
#  [1, 2, 569, 586, 4165],
#  [349, 571, 76, 1, 76, 11, 94, 11, 39, 313, 795, 1, 138, 329, 329],
#  [1, 342],
#  [3, 1, 316],
#  [1, 516, 103, 309],
#  [1, 2, 3575, 3306, 13231, 26279, 108, 267, 33, 90, 117, 281, 7, 2069],
#  [71, 14, 1158, 331],
#  [1427,
#   1393,
#   17,
#   246,
#   4685,
#   214,
#   2929,
#   1617,
#   1210,
#   83,
#   2238,
#   588,
#   10165,
#   2949,
#   560,
#   182,
#   246,
#   1,
#   384,
#   1004],
#  [66, 166, 1, 2347, 1450, 234, 51, 789, 79, 2],
#  [12,
#   25,
#   32,
#   31,
#   170,
#   30,
#   16527,
#   20,
#   55,
#   1081,
#   126,
#   2479,
#   1,
#   13,
#   26,
#   375,
#   1,
#   2,
#   1785,
#   860,
#   139],
#  [1108, 2608, 1, 479],
#  [1, 297, 152, 243, 98, 988, 978, 115, 89, 26280],
#  [3, 1, 1025, 50, 847, 1323],
#  [71,
#   1316,
#   2016,
#   110,
#   941,
#   1367,
#   272,
#   1002,
#   62,
#   241,
#   247,
#   1189,
#   1,
#   219,
#   60,
#   1697,
#   31,
#   126],
#  [3, 1, 42, 308, 8166, 18],
#  [1, 340],
#  [142, 1, 2, 807, 620, 304, 24, 1229, 23],
#  [85, 2253, 2128, 1, 6, 215, 2098, 6],
#  [1, 361, 71, 398, 14, 70, 152, 806],
#  [1, 782, 27, 148, 53, 2, 2313, 1914, 94, 210],
#  [11,
#   1,
#   826,
#   128,
#   69,
#   7,
#   33,
#   49,
#   6,
#   2,
#   11,
#   2322,
#   957,
#   18,
#   33,
#   414,
#   11420,
#   30,
#   150,
#   16,
#   8,
#   1,
#   204],
#  [1, 642, 50],
#  [11, 72, 147, 238, 1076, 200, 106, 97, 164, 444, 106, 2, 1, 524],
#  [128, 80, 59, 27, 222, 203, 40, 58, 1, 2, 655, 4, 3],
#  [1, 167, 473, 116],
#  [1, 1041, 1676, 597, 19477, 3746, 2637, 1581],
#  [3,
#   1,
#   701,
#   375,
#   2582,
#   1013,
#   7909,
#   35,
#   188,
#   1648,
#   3864,
#   325,
#   38,
#   2500,
#   274,
#   40,
#   264,
#   551,
#   17,
#   5,
#   13,
#   2625],
#  [11, 235, 4251, 300, 893, 176, 1, 226, 8, 458, 34, 326, 893],
#  [1, 1296, 261, 96, 51, 58],
#  [245, 2, 1, 384, 671, 107, 637, 22, 92, 21, 349],
#  [749, 1, 315, 12, 727],
#  [968,
#   1,
#   190,
#   76,
#   66,
#   152,
#   150,
#   3637,
#   206,
#   123,
#   113,
#   1018,
#   1020,
#   113,
#   104,
#   38,
#   16,
#   9,
#   13232,
#   7,
#   25,
#   38],
#  [1, 850, 18, 67, 1427, 5, 6, 6, 850, 1],
#  [191, 724, 343, 2209, 273, 111, 533, 201, 2571, 7209, 59, 364, 1576],
#  [1, 151, 1548, 462, 611, 1035, 37, 112],
#  [11, 62, 16, 120, 64, 300, 3, 1, 570, 3502, 84],
#  [1, 151, 361, 66, 6, 680, 563, 6, 404, 24, 1375, 111],
#  [34, 650, 161, 48, 60, 7, 893, 386, 18, 29, 1, 499],
#  [1, 351, 640, 353, 22, 46, 1607, 24],
#  [29, 1, 436, 1451],
#  [387,
#   120,
#   462,
#   2005,
#   1330,
#   90,
#   96,
#   235,
#   324,
#   3265,
#   1,
#   408,
#   735,
#   235,
#   324,
#   3265],
#  [592,
#   2025,
#   6801,
#   146,
#   3457,
#   6801,
#   12,
#   15,
#   5418,
#   1,
#   3,
#   44,
#   6,
#   11,
#   4086,
#   1603,
#   4813],
#  [1, 217, 426, 270, 63, 218, 53, 272, 417, 4527, 272, 14630, 2323, 113, 2525],
#  [1, 2, 225, 3903, 1, 67, 1612, 376, 24],
#  [3, 145, 1, 615, 34, 36, 212, 2572, 198, 1653],
#  [1, 467, 90, 110, 583],
#  [352,
#   1,
#   83,
#   63,
#   1710,
#   1720,
#   201,
#   35,
#   3981,
#   63,
#   1,
#   75,
#   83,
#   4585,
#   35,
#   3981,
#   49,
#   11421,
#   638,
#   825],
#  [27, 8, 238, 178, 293, 1, 92],
#  [21, 145, 1, 1427, 1173, 124, 85, 143, 67, 412, 143, 198, 779],
#  [3, 42, 73, 3533, 252, 135, 377, 3, 293, 6802, 98, 8, 1, 569, 2227],
#  [1, 20, 796, 856, 3063, 13233, 1934, 126, 20, 878, 26281, 429],
#  [4,
#   1100,
#   1094,
#   38,
#   1205,
#   183,
#   1412,
#   168,
#   183,
#   3429,
#   162,
#   3331,
#   16,
#   111,
#   1,
#   470,
#   167,
#   7,
#   1174],
#  [1, 320, 43, 36, 38],
#  [555, 1, 393, 52, 4585],
#  [242, 64, 7425, 1919, 50, 124, 1, 16528, 810],
#  [111, 557, 877, 1039, 22, 878, 43, 60, 1, 640],
#  [32, 1, 4087, 2567, 88, 658, 126, 2469, 36, 208],
#  [86,
#   180,
#   79,
#   10,
#   295,
#   348,
#   8,
#   1,
#   2,
#   1280,
#   3103,
#   40,
#   245,
#   59,
#   8,
#   660,
#   104,
#   1,
#   3,
#   327],
#  [413,
#   1,
#   1263,
#   1537,
#   14,
#   543,
#   669,
#   325,
#   533,
#   5521,
#   2348,
#   1,
#   1263,
#   14,
#   533,
#   10166,
#   1996,
#   7,
#   3353,
#   712,
#   1,
#   1263,
#   8836,
#   902,
#   843,
#   19478,
#   3353],
#  [1, 380, 12, 352],
#  [1, 3014, 70, 562, 533, 1003, 1188],
#  [4, 1, 380, 85, 676, 7660, 49, 58, 1468, 24, 1032, 4252, 13234],
#  [1, 824, 76, 127, 2872],
#  [21, 1, 167, 116, 57, 426, 299, 278, 403, 308],
#  [1,
#   327,
#   209,
#   124,
#   5720,
#   111,
#   118,
#   727,
#   358,
#   2583,
#   10743,
#   33,
#   253,
#   25,
#   21,
#   58,
#   3,
#   888,
#   82,
#   900,
#   7210,
#   35,
#   527],
#  [1, 645, 59],
#  [1, 475, 2191, 770, 60, 38, 117, 1584],
#  [3, 1773, 73, 15, 40, 1, 359, 59, 4],
#  [1, 2, 1300, 9688],
#  [290, 58, 334, 84, 37, 19479, 37, 58, 1, 45, 19479, 506],
#  [387, 159, 902, 1521, 3045, 550, 3045, 202, 1, 6, 230, 41],
#  [140,
#   1281,
#   111,
#   1449,
#   6,
#   1,
#   2,
#   122,
#   6,
#   10,
#   865,
#   865,
#   33,
#   248,
#   731,
#   742,
#   5,
#   487],
#  [1, 259, 1938, 201],
#  [11, 69, 45, 105, 1, 647],
#  [3, 1, 615, 20, 554, 139],
#  [1, 767, 1174, 121, 215],
#  [3, 1, 526, 21, 107, 41, 3354, 98],
#  [1, 2, 237, 317, 566, 1881],
#  [1, 2898, 259, 64, 932, 95, 1389],
#  [1, 6, 470, 41, 111, 2526, 26282, 3203, 31, 4429],
#  [29, 1, 813, 14, 2256, 3, 1127],
#  [417, 525, 947, 6630, 2424, 947, 1, 773, 309],
#  [3, 27, 1, 127, 481, 2372, 41],
#  [36, 78, 1230, 7, 330, 1, 2, 129, 5834, 611],
#  [1, 415, 746],
#  [1, 383, 20, 850, 17, 27, 807, 103, 24, 386],
#  [1, 40, 12253, 504, 1831],
#  [52, 71, 6190, 4528, 1377, 1, 567, 259],
#  [1, 2, 904, 544, 268, 5, 933, 268, 5721, 138],
#  [1, 757, 268, 4750, 43, 5083, 18],
#  [4, 4, 352, 125, 8, 1, 597],
#  [44, 373, 2349, 1192, 1039, 1479, 1, 2, 1192, 1039, 1479],
#  [12, 1, 291, 2913, 1090, 2171],
#  [10,
#   379,
#   37,
#   22,
#   52,
#   1057,
#   2109,
#   834,
#   2264,
#   848,
#   52,
#   76,
#   25,
#   1,
#   52,
#   1806,
#   19480,
#   112],
#  [749, 764, 1, 432],
#  [494, 1, 11, 665, 651, 96, 1],
#  [129, 2584, 228, 29, 5, 78, 328, 849, 2180, 583, 1, 449],
#  [239, 54, 1, 295, 438, 93, 1127, 770],
#  [1, 26, 135, 207, 90, 226, 334, 170, 45],
#  [1, 433, 153, 877, 33, 173, 14631, 8, 709],
#  [1, 190, 38, 927, 561, 130, 84, 126, 4],
#  [1, 430, 62, 1328],
#  [1, 2, 4529, 425, 166],
#  [1, 477],
#  [70,
#   3458,
#   5522,
#   4627,
#   21,
#   78,
#   143,
#   13,
#   153,
#   1,
#   505,
#   7,
#   207,
#   463,
#   90,
#   1240,
#   35,
#   99,
#   6191,
#   1188,
#   104,
#   196,
#   650,
#   1373,
#   90,
#   24],
#  [82, 5, 11, 1849, 59, 15, 204, 2828, 1154, 1, 11, 5523, 326],
#  [345,
#   857,
#   139,
#   19,
#   392,
#   731,
#   2129,
#   3430,
#   237,
#   889,
#   283,
#   124,
#   2391,
#   1249,
#   45,
#   1,
#   21,
#   340,
#   84],
#  [122, 705, 1, 4017, 950, 1721, 9, 69, 26283],
#  [480, 1, 190, 101],
#  [3, 1, 245, 535, 50],
#  [11, 1, 47],
#  [44, 22, 1, 2, 9, 875, 776, 3, 73],
#  [1,
#   707,
#   1413,
#   2110,
#   1108,
#   113,
#   480,
#   628,
#   651,
#   251,
#   3830,
#   110,
#   1413,
#   11,
#   462,
#   5835],
#  [43, 1, 83, 326, 109, 7, 24],
#  [1,
#   2,
#   70,
#   94,
#   6986,
#   44,
#   155,
#   698,
#   1618,
#   1314,
#   207,
#   698,
#   3288,
#   1095,
#   1021,
#   1620,
#   718,
#   26284,
#   180,
#   66,
#   126,
#   1213,
#   7,
#   5011,
#   200],
#  [1, 2, 569, 1002, 3, 7],
#  [1, 918, 8, 110, 70, 2807],
#  [3, 1, 601, 615, 2, 235, 5621],
#  [15, 1, 477],
#  [12, 2626, 197, 775, 56, 222, 390, 274, 1, 250, 132],
#  [54, 1, 22, 155],
#  [48,
#   982,
#   1,
#   2708,
#   835,
#   14632,
#   3503,
#   294,
#   794,
#   15,
#   8,
#   118,
#   986,
#   429,
#   4299,
#   2430],
#  [279, 1, 321],
#  [1, 929],
#  [138, 1, 2, 1271, 182, 512, 346, 7],
#  [3, 44, 1, 317, 119, 974, 792, 510, 1807, 1147, 607],
#  [43, 36, 636, 1, 327],
#  [99, 101, 1, 481, 149, 63],
#  [1, 145, 283, 378, 210, 382, 224, 1997, 1873],
#  [145, 1, 408, 66, 715, 34, 2930],
#  [10, 8, 57, 1, 403],
#  [15, 1, 471, 17, 13, 14],
#  [1, 2, 1005, 556],
#  [1, 11, 215, 24],
#  [28, 12, 32, 920, 165, 18, 1, 523],
#  [66, 38, 1, 5084, 774, 414, 525, 823, 779, 113, 912, 698, 44, 377],
#  [80, 98, 259, 2397, 110, 98, 120, 1, 848, 567, 1197],
#  [1, 12, 221, 444, 44, 43, 112, 164, 735],
#  [350, 322, 1, 85, 7, 394, 1, 458],
#  [369, 1126, 1159, 67, 145, 1938, 53, 165, 248, 278, 248, 12254, 287, 1159],
#  [1, 745, 189, 644, 411],
#  [1, 55, 24, 580, 345, 829, 79],
#  [783, 193, 18, 1, 457, 102, 399, 831, 1465],
#  [1, 6, 1198],
#  [1126, 30, 158, 58, 1, 509, 224, 277, 201, 16, 15, 218, 332],
#  [184, 1, 2, 10, 76, 95, 11, 76, 95],
#  [1, 290, 114, 281, 7, 117, 61, 2201, 25, 2765, 4751, 852, 272, 2553, 326],
#  [60, 2075, 2373, 160, 1154, 1311, 1, 2, 10, 188, 11, 1265, 1808],
#  [1, 280, 1263, 796],
#  [48, 178, 728, 1, 255, 149, 157],
#  [1, 514, 852, 262, 1, 1403, 231, 482],
#  [1, 252, 47, 244, 465, 7],
#  [598,
#   84,
#   2033,
#   916,
#   1068,
#   661,
#   5,
#   38,
#   2172,
#   1571,
#   1,
#   55,
#   584,
#   2162,
#   3984,
#   5085],
#  [1, 531, 205, 1222, 1076],
#  [311, 249, 66, 1186, 1, 249, 20, 1419, 503, 1],
#  [1, 621, 403],
#  [387, 335, 829, 1949, 7],
#  [3, 73, 1, 355, 161],
#  [9, 314, 1, 215],
#  [1, 593, 788, 596, 3139, 63, 755, 875, 203, 9, 2146, 203],
#  [3, 976, 914, 7, 90, 3124, 1, 2, 1058, 150, 1321, 13, 248],
#  [30, 1661, 8, 1176, 635, 6803, 2585, 51, 1, 515, 187, 374, 429],
#  [4, 626, 1596, 829, 714, 1087, 554, 1, 92, 143, 45],
#  [1, 267, 252],
#  [455, 488, 1, 473],
#  [1, 361],
#  [1, 55, 489, 3332, 1336, 4942, 206],
#  [11, 8, 1, 519, 43, 411],
#  [3, 57, 844, 661, 5, 92, 1, 478, 8, 527],
#  [299, 1, 7, 2741, 649, 7, 1, 164, 84, 2766, 1403],
#  [1, 541, 1209, 1184, 301, 972],
#  [21, 1, 647, 136, 345, 6, 1, 64, 136],
#  [85, 1, 65, 859, 556],
#  [232,
#   4166,
#   101,
#   77,
#   927,
#   1987,
#   1189,
#   152,
#   268,
#   1275,
#   10744,
#   37,
#   1,
#   275,
#   50,
#   3,
#   152],
#  [1, 665, 272, 12, 95, 874],
#  [48, 1, 508, 560, 5, 902, 26285, 1639, 106, 607],
#  [413, 1021, 3307, 2609, 2350, 1, 42, 752],
#  [1, 2, 3, 1561, 1, 213, 8, 20, 214],
#  [1, 205, 113, 112, 4, 9, 1037, 208, 1904],
#  [1, 833, 575, 16529, 7, 162, 988, 792, 5951, 223, 31, 67, 731, 257, 12255],
#  [1, 4, 20, 55, 52, 226, 2, 211, 1011, 1303],
#  [1,
#   26,
#   70,
#   55,
#   495,
#   9,
#   139,
#   1269,
#   1331,
#   37,
#   7211,
#   191,
#   150,
#   13,
#   1709,
#   312,
#   955,
#   851],
#  [3, 1, 487, 2554, 184, 19, 6631, 672, 16530],
#  [1, 424, 445, 328],
#  [19, 1, 190, 268],
#  [2291, 121, 2044, 146, 1, 224, 387, 170, 954, 88],
#  [1, 919, 4, 484, 423],
#  [4, 577, 682, 964, 1059, 909, 1, 2, 363, 440],
#  [1, 199, 2292, 697, 266, 27, 99, 298],
#  [1, 2, 633, 84, 9, 330, 810, 7, 3, 250, 151],
#  [1, 271, 3, 49, 10, 9, 46, 7],
#  [1, 346, 347, 346, 4, 73],
#  [1,
#   3721,
#   150,
#   190,
#   14633,
#   11,
#   128,
#   100,
#   1053,
#   13235,
#   96,
#   411,
#   548,
#   2272,
#   678,
#   1807,
#   4205,
#   14633,
#   341,
#   293,
#   4126],
#  [32, 1, 613, 379, 1489, 211, 884, 81, 644],
#  [61, 6316, 53, 1301, 659, 265, 43, 1, 151, 490, 1077, 64],
#  [1, 6, 395, 57, 772, 1104, 59, 3158, 38, 7, 46, 1593, 388],
#  [8,
#   273,
#   124,
#   54,
#   1,
#   2,
#   1,
#   471,
#   258,
#   679,
#   2147,
#   598,
#   144,
#   19,
#   5,
#   38,
#   3156,
#   182,
#   1225],
#  [1, 2562, 2, 16531, 14634],
#  [3, 19, 293, 90, 3985, 589, 2257, 368, 293, 5, 1203, 8, 257, 1, 13, 548],
#  [1, 657, 487, 349],
#  [28, 4, 119, 1704, 1, 186, 1559, 136, 52],
#  [2045, 5722, 170, 1, 163],
#  [1, 214, 3015, 11, 190],
#  [1, 986, 1153, 272, 9231],
#  [184, 1476, 1738, 1, 416, 101],
#  [1, 558, 1532, 49, 1541],
#  [6, 11, 320, 1, 346, 1480],
#  [9, 1, 245, 642],
#  [3,
#   46,
#   1114,
#   1,
#   2,
#   6,
#   691,
#   1044,
#   28,
#   968,
#   1017,
#   5952,
#   16,
#   410,
#   17,
#   97,
#   206,
#   62],
#  [3, 1, 236],
#  [1, 1054, 1029, 5953],
#  [3, 1, 19481, 2006, 418, 6798, 26286],
#  [227,
#   279,
#   74,
#   296,
#   15,
#   1,
#   8837,
#   1107,
#   575,
#   246,
#   127,
#   258,
#   7426,
#   175,
#   12,
#   1963,
#   1021,
#   25,
#   1151,
#   755],
#  [1, 567, 167, 18],
#  [350, 1, 165, 17, 7, 3, 430, 25, 909, 16532],
#  [30, 1, 57, 30, 52, 24, 3140],
#  [34, 36, 130, 2122, 223, 187, 2506, 922, 45, 781, 1, 2, 129, 62],
#  [224, 1035, 31, 21, 129, 62, 16533, 1728, 730, 1, 651, 767],
#  [3,
#   758,
#   1032,
#   6,
#   29,
#   2873,
#   20,
#   1048,
#   687,
#   1,
#   6,
#   150,
#   10745,
#   869,
#   1652,
#   83,
#   670],
#  [1, 768, 16, 834, 14635, 101, 57, 3289, 282],
#  [1, 144, 93, 1380, 1399, 118],
#  [1, 500, 517, 2950, 1021, 26287],
#  [1842, 1001, 103, 1827, 1, 194],
#  [9, 31, 47, 4385, 1, 26, 392, 996, 8167],
#  [31, 171, 798, 1373, 209, 105, 1, 135],
#  [1, 543, 172],
#  [1, 582, 61, 79, 24, 12, 194, 399, 1042, 379, 61, 298],
#  [1, 566, 98, 115, 89, 7212],
#  [24, 722, 48, 39, 3, 349, 5163, 2996, 2239, 2, 69, 560, 786, 3, 1, 394],
#  [54, 5, 22, 160, 581, 3, 1, 26, 2610, 80, 230, 50],
#  [3, 1, 1341, 322, 751, 69, 13, 16],
#  [1, 361, 21, 51, 6, 520, 469, 182, 898],
#  [1, 312, 899, 510, 45, 85, 2209, 19, 86, 4333],
#  [6317, 5836, 19482, 26288, 86, 153, 30, 25, 128, 1, 1205, 310, 300],
#  [1,
#   2,
#   2374,
#   5012,
#   3501,
#   10746,
#   53,
#   2611,
#   834,
#   236,
#   1459,
#   1164,
#   2720,
#   26289,
#   3865,
#   690],
#  [3, 1, 582, 509],
#  [1, 219, 5, 990, 1635, 1978],
#  [1, 2, 32, 225, 532, 127, 15, 68, 137, 6987, 2258, 12256, 6460],
#  [19, 1, 1136, 691, 2347, 1897, 3504, 114, 336, 2425],
#  [60, 206, 690, 65, 5419, 1324, 5, 3576, 1603, 3089, 38, 1450, 8, 1, 332],
#  [1, 166, 4, 159, 2426, 15, 435, 300, 2, 684, 3577, 1918, 5164, 96, 1348],
#  [1, 492, 259],
#  [1574,
#   1230,
#   633,
#   162,
#   878,
#   1,
#   301,
#   2438,
#   35,
#   178,
#   188,
#   484,
#   185,
#   20,
#   528,
#   1123,
#   992],
#  [10,
#   1,
#   77,
#   551,
#   563,
#   10,
#   639,
#   273,
#   595,
#   814,
#   3125,
#   10,
#   197,
#   25,
#   658,
#   25,
#   2537,
#   33,
#   38,
#   260,
#   232],
#  [1564, 1, 505, 3804, 5086, 1074, 156, 1488],
#  [1, 1487, 231, 9, 1556],
#  [1, 4, 1, 251, 497, 84, 279, 10, 8, 1120, 82, 113, 9],
#  [3, 4334, 1, 199, 146, 241, 55, 35, 4253, 113, 14, 300, 41, 1031, 41],
#  [10, 107, 110, 1, 2, 225, 104],
#  [1, 1194, 775, 896, 174, 2454, 333],
#  [1, 475, 2976, 8, 238, 1678],
#  [1082, 4, 1, 141, 6988, 362, 17, 45, 3482],
#  [85, 1121, 378, 331, 210, 1, 267, 124, 66],
#  [1, 2, 39, 394, 79, 729],
#  [177, 61, 86, 4, 384, 84, 1246, 142, 1, 76, 77, 1444, 545, 1444],
#  [15,
#   1,
#   492,
#   2042,
#   1653,
#   9,
#   2966,
#   257,
#   4167,
#   3610,
#   159,
#   2638,
#   1059,
#   565,
#   26290,
#   26291,
#   14636,
#   2638],
#  [3, 1, 548, 169, 408, 6070, 818, 23, 345],
#  [4, 14, 1, 307, 16534, 183, 31],
#  [1, 1141, 392, 167, 4488, 106, 3377],
#  [1, 2, 124, 3, 18, 257, 34, 75, 634],
#  [191, 78, 1, 121, 355, 2470, 166],
#  [6, 305, 2, 183, 188, 94, 1, 543, 930, 291],
#  [635, 851, 148, 1, 571, 20, 878, 516, 1390, 29, 76],
#  [3, 61, 56, 1, 267, 62, 435, 1222, 1049, 974, 125],
#  [1, 255, 2821, 71, 23],
#  [29, 317, 141, 33, 200, 1672, 1652, 82, 67, 1, 13, 392, 149, 151, 328],
#  [10, 1, 625, 683, 5622],
#  [1, 1069, 1084, 20, 417, 1209, 873, 2538, 9, 184, 26292],
#  [1, 11, 2064],
#  [8, 1, 741],
#  [4530, 123, 800, 366, 69, 1, 791, 2, 2403],
#  [1, 6, 361, 14, 112, 19, 333, 7, 847, 1764],
#  [61, 1320, 3, 9, 1, 13, 582],
#  [10, 381, 490, 279, 4, 227, 1, 113, 199, 246, 175, 33, 6461, 1190],
#  [10, 19483, 10167, 337, 1, 2, 93],
#  [1, 844, 6, 93, 87, 3, 19],
#  [388,
#   26293,
#   20,
#   590,
#   60,
#   117,
#   107,
#   999,
#   2281,
#   586,
#   3747,
#   2573,
#   411,
#   16,
#   30,
#   61,
#   893,
#   58,
#   8168,
#   577,
#   204,
#   107,
#   58,
#   1,
#   419,
#   2282,
#   115,
#   89,
#   1898],
#  [35, 90, 16, 1, 619],
#  [52, 891, 52, 9, 1095, 1, 156, 185],
#  [1, 195, 3, 816, 139, 13236],
#  [8, 73, 17, 98, 849, 305, 67, 36, 170, 654, 7, 12, 14, 1, 275, 149, 849],
#  [1, 11, 2163, 327],
#  [3, 1, 26, 1667],
#  [1, 186, 18, 550, 1213, 91, 26294, 195, 964, 2106, 36],
#  [1, 2, 225, 7, 126, 200, 8, 1597, 1106, 193, 17],
#  [3, 4206, 1, 403],
#  [1, 308, 1721, 1966, 373],
#  [1079, 1, 294],
#  [2967, 156, 9, 58, 1, 230, 49, 156, 74, 27, 5, 362, 170],
#  [30, 626, 588, 1, 1724, 47, 46, 100, 682, 712],
#  [1, 26, 2065, 474, 1043, 460, 784, 24, 464, 109, 7, 29, 2333, 45, 412],
#  [43, 955, 147, 1, 489, 839, 104, 5241, 685, 812],
#  [29, 1, 199, 15, 82, 3064, 336, 35, 578, 196, 16, 552],
#  [1, 457, 289, 2507, 31, 82, 35, 31, 9689, 318],
#  [3,
#   35,
#   174,
#   1,
#   55,
#   790,
#   460,
#   22,
#   7,
#   1899,
#   3,
#   85,
#   641,
#   707,
#   1041,
#   679,
#   133,
#   38],
#  [82, 31, 18, 550, 18, 82, 1, 269, 8169, 20, 73, 671, 5, 3204, 222],
#  [1282, 91, 1, 2, 584, 257, 954],
#  [396, 63, 1, 993, 396, 36],
#  [1, 292, 17, 379, 24],
#  [1, 2, 30, 62, 155],
#  [3, 1, 307, 911, 6462],
#  [4,
#   3013,
#   13237,
#   1,
#   861,
#   599,
#   324,
#   1967,
#   2767,
#   393,
#   126,
#   200,
#   13237,
#   3431,
#   75,
#   3481],
#  [1, 2, 491, 769, 122, 117, 11],
#  [1859, 1, 320, 250],
#  [111, 171, 1, 237, 593, 79],
#  [1, 768, 2856, 7],
#  [1, 443],
#  [1, 850],
#  [35, 578, 193, 1, 437, 2694, 1021, 16535, 561, 4386],
#  [1, 20, 269],
#  [583,
#   184,
#   1480,
#   1105,
#   2164,
#   2822,
#   1381,
#   13,
#   19484,
#   3,
#   6,
#   26295,
#   58,
#   1,
#   118,
#   691],
#  [1011, 3505, 12257, 32, 122, 1, 380, 122, 1662, 10],
#  [44, 52, 1, 27, 4874, 381, 1325, 549, 222, 194],
#  [279, 1, 472, 243, 528, 819, 152, 2857],
#  [1691, 552, 7, 17, 101, 58, 1, 6192, 648, 368, 1850, 939, 1080],
#  [1, 571, 1, 2574],
#  [1, 287, 408],
#  [1,
#   443,
#   580,
#   7,
#   880,
#   26296,
#   1,
#   23,
#   48,
#   26297,
#   120,
#   5,
#   1676,
#   728,
#   2,
#   662,
#   26298,
#   1259,
#   662,
#   404],
#  [3, 1, 449],
#  [1, 2, 14637, 407, 47, 26299, 171, 43, 587, 120, 242, 4207, 835, 16536, 877],
#  [44, 35, 12, 23, 874, 1, 986],
#  [1, 2, 69, 18, 973, 2228, 404, 165, 632, 706],
#  [3, 309, 1, 571, 3611, 3, 308, 592, 532, 41, 1091, 154, 143, 898],
#  [44, 1, 2, 23, 111, 374],
#  [19, 1, 1794, 449],
#  [132, 134, 72, 110, 941, 381, 1, 10, 2259, 541, 493, 9, 997],
#  [1, 406, 1276, 41, 1813, 2087, 125, 161, 125, 1535, 45, 412],
#  [1, 77, 437, 6, 102, 7, 124, 56, 502, 317, 398, 248, 204, 1909, 7],
#  [3,
#   78,
#   510,
#   1106,
#   3,
#   2563,
#   1249,
#   994,
#   1497,
#   3,
#   1,
#   647,
#   586,
#   337,
#   103,
#   148,
#   182],
#  [54, 6, 1, 103, 59, 15],
#  [4430, 1, 341, 665],
#  [2045, 31, 1, 118, 603],
#  [28, 152, 1403, 91, 1671, 16, 1060, 71, 7, 1, 2, 5, 1069, 1982],
#  [219, 10747, 1654, 1, 294, 29, 90, 1718, 914],
#  [6, 2120, 7, 31, 1160, 110, 529, 192, 96, 156, 1, 665, 50, 945, 864, 89],
#  [145,
#   2334,
#   855,
#   9690,
#   71,
#   241,
#   1572,
#   724,
#   1,
#   55,
#   106,
#   70,
#   40,
#   93,
#   944,
#   185,
#   267,
#   1056],
#  [32, 19, 765, 5, 1744, 1397, 714, 847, 53, 562, 61, 120, 695, 1, 1385, 84],
#  [51, 59, 15, 9, 1, 103, 198, 685, 25, 54, 349, 905, 518, 1, 23, 263, 435],
#  [227, 1, 505],
#  [290, 338, 925, 26, 1, 1351, 1, 365, 2501, 436],
#  [26300, 1, 2099, 26301],
#  [1, 22, 452, 2216],
#  [1, 355, 46, 26302, 927],
#  [417,
#   386,
#   815,
#   4752,
#   36,
#   19485,
#   1851,
#   1374,
#   680,
#   106,
#   58,
#   1,
#   394,
#   2502,
#   1167,
#   85,
#   1422,
#   1561],
#  [48, 1355, 12, 2, 1, 443],
#  [30, 65, 3178, 1162, 184, 672, 1949, 104, 9, 20, 1, 536],
#  [1, 535, 31, 2655, 81, 20, 6632, 161, 29, 136, 20, 1467, 11422],
#  [54, 1, 852, 1246, 189, 418, 733, 39, 53, 3378],
#  [1, 42, 274, 26303],
#  [1, 467, 3308, 106, 4531, 19486],
#  [176,
#   10,
#   1997,
#   662,
#   38,
#   934,
#   7,
#   2951,
#   1205,
#   676,
#   510,
#   614,
#   586,
#   3506,
#   67,
#   184,
#   53,
#   1,
#   585],
#  [60, 1, 20, 470, 2728],
#  [1, 323],
#  [1, 2, 569, 912],
#  [99, 1, 286, 108, 900, 126],
#  [1, 103, 9, 168, 9, 168, 891, 197],
#  [1, 507, 1652],
#  [1, 597, 391],
#  [3, 1, 26, 479, 50, 130],
#  [1, 767, 50],
#  [775, 152, 495, 1, 185, 267],
#  [102,
#   1,
#   244,
#   13238,
#   13238,
#   2260,
#   1611,
#   4,
#   13,
#   2350,
#   974,
#   5,
#   119,
#   268,
#   16537,
#   12258,
#   5,
#   878],
#  [164, 7427, 764, 994, 2173, 204, 1, 57, 55, 388, 34, 320, 1082, 9, 204, 337],
#  [1,
#   633,
#   19,
#   331,
#   197,
#   111,
#   545,
#   3064,
#   2148,
#   6193,
#   3227,
#   1152,
#   7213,
#   2997,
#   147,
#   1150,
#   47,
#   18],
#  [99,
#   37,
#   3046,
#   87,
#   71,
#   2741,
#   1508,
#   2109,
#   134,
#   10168,
#   71,
#   658,
#   4628,
#   6,
#   1,
#   215],
#  [39, 1, 267, 57],
#  [1, 450, 17, 1222, 928],
#  [66,
#   170,
#   1,
#   717,
#   885,
#   697,
#   826,
#   60,
#   516,
#   1070,
#   9691,
#   191,
#   129,
#   85,
#   1224,
#   19487,
#   78],
#  [10,
#   174,
#   11,
#   11,
#   1223,
#   1,
#   6,
#   292,
#   254,
#   30,
#   2088,
#   790,
#   301,
#   1285,
#   790,
#   217,
#   88],
#  [1, 283, 4875, 367, 183],
#  [3, 145, 26, 304, 1914, 2709, 1, 8170, 70, 227, 25],
#  [1, 320, 5524, 1144, 1026, 4335, 992, 254, 10169, 373],
#  [1, 487, 214, 336, 445, 1977],
#  [3, 261, 366, 181, 18, 1, 241, 836, 344, 234, 4, 16, 368, 102],
#  [1855,
#   2360,
#   831,
#   6989,
#   1,
#   249,
#   1556,
#   13239,
#   3030,
#   199,
#   12259,
#   1070,
#   47,
#   994,
#   252,
#   6990,
#   1778,
#   147],
#  [1, 236, 139, 3666],
#  [442, 158, 1, 164, 1041, 9, 187, 33, 13, 2846, 96],
#  [3, 73, 9, 1, 536, 6463, 1337, 155, 1620],
#  [1, 2, 785, 3866, 1326],
#  [39, 1, 619, 1679, 38, 1343, 2258],
#  [172, 38, 1, 450, 176, 1, 492, 55],
#  [21, 1108, 1, 11, 21, 1583, 1008, 223, 1178],
#  [1, 215, 804],
#  [350, 1, 1041, 1322, 164],
#  [1, 596, 14, 303, 583, 241],
#  [1, 15, 9, 65, 102, 33, 52, 11, 4814, 13240],
#  [1, 69, 7, 33, 655, 153],
#  [1, 127, 852, 418, 3722, 1203, 1144, 1476],
#  [1, 555, 233, 279, 91, 968, 919, 129, 171, 30, 2066, 101, 34, 822],
#  [3, 1, 497, 778, 115, 89, 371],
#  [32, 1, 213, 555, 568, 45, 235, 733],
#  [1, 453, 1, 453, 115, 89, 16538],
#  [1, 2, 306, 806, 9, 1806],
#  [3, 1, 361, 70, 33, 2174, 65, 1122],
#  [289, 240, 59, 25, 32, 1, 249, 208, 472],
#  [1018, 314, 273, 599, 780, 1, 121, 135, 385, 211, 1108, 935, 2808],
#  [1, 2, 27, 137],
#  [1, 580, 1546, 4, 139, 19, 1066],
#  [8, 73, 140, 1490, 836, 16, 8, 57, 20, 3141, 47, 1290, 1, 618, 119, 84, 7],
#  [311, 129, 14638, 22, 1, 457, 257, 2375],
#  [258,
#   118,
#   304,
#   1,
#   425,
#   523,
#   105,
#   98,
#   144,
#   2,
#   1683,
#   294,
#   147,
#   1722,
#   860,
#   26304,
#   115,
#   89,
#   26305],
#  [1, 304, 628, 265, 1389],
#  [3, 1, 119, 1077, 42, 544, 3, 1, 119, 26306, 987],
#  [99, 1, 487, 2122, 10170, 3985, 2858, 232, 1140, 147],
#  [1, 26307, 310],
#  [1, 475, 81],
#  [3, 1, 256, 603, 1520, 19488, 2046, 210, 2245, 210, 2314, 1286],
#  [54, 1, 138, 74, 42, 185],
#  [1, 964, 753, 558, 16, 2, 1968, 2302, 78, 5, 9232, 1070, 1021],
#  [59, 144, 13241, 1, 1307, 36, 575, 167],
#  [1, 930, 269, 63, 3],
#  [3,
#   1,
#   505,
#   4300,
#   7214,
#   1814,
#   938,
#   13,
#   671,
#   1051,
#   4753,
#   32,
#   8,
#   3986,
#   17,
#   238,
#   687,
#   1882,
#   120,
#   152,
#   25,
#   235,
#   78],
#  [1, 745, 299, 411, 2552],
#  [1, 483, 241, 23, 450],
#  [19, 1, 593, 660, 250],
#  [1, 80, 446, 10748],
#  [1, 519, 917, 859, 182],
#  [19, 1831, 79, 2375, 226, 198, 1, 274, 690, 196, 552, 265],
#  [6, 27, 113, 1, 426, 41],
#  [1, 65, 384, 804],
#  [1, 702, 1174],
#  [21, 734, 2324, 2303, 31, 445, 176, 1, 213, 12, 1697],
#  [1, 767, 31, 940, 50],
#  [39,
#   1,
#   2,
#   1376,
#   88,
#   762,
#   501,
#   35,
#   60,
#   875,
#   6804,
#   1669,
#   6,
#   1895,
#   1687,
#   19489,
#   6194,
#   178,
#   674,
#   3309,
#   7,
#   1053,
#   132,
#   40,
#   39,
#   6318],
#  [322, 1, 291, 46, 868, 100, 343, 654, 124, 1256],
#  [19, 1, 219, 1701],
#  [1, 504, 2149, 975, 684, 1118],
#  [39, 17, 30, 532, 1, 51, 107, 192, 377, 222, 202, 28, 174, 14, 1, 496],
#  [1, 2471, 1192, 560, 1136],
#  [1, 309, 59, 6071, 70, 198, 3534, 550, 45],
#  [1, 2, 571, 837, 380],
#  [239, 1843, 171, 4, 14, 66, 1, 52, 969, 414],
#  [28, 201, 633, 241, 560, 708, 1, 430, 227],
#  [3, 1, 269, 1672, 2335, 1795, 2283, 64, 2, 989, 747, 238, 1205],
#  [3, 1, 26, 594, 50, 249, 620, 684, 11423, 1297],
#  [1, 22, 1146, 502, 5, 418, 5837, 3031, 3483, 184],
#  [1, 2, 1701, 449],
#  [34, 150, 1705, 1882, 19490, 23, 20, 11424, 7428, 1, 2, 26, 129, 1195],
#  [1,
#   558,
#   578,
#   3047,
#   917,
#   848,
#   1904,
#   9233,
#   806,
#   40,
#   1131,
#   90,
#   2209,
#   464,
#   2080,
#   76,
#   145,
#   156,
#   264],
#  [3, 1, 416, 540, 129, 7, 22],
#  [74, 797, 1, 6, 457],
#  [47, 12, 742, 11, 125, 1, 13, 392],
#  [1, 2, 491, 769, 527],
#  [1, 478],
#  [1, 2, 9, 150, 133],
#  [1, 415, 469, 48, 797, 10, 184, 4754, 10, 264, 314, 3379, 749, 318, 181, 16],
#  [60, 1, 57, 1, 38],
#  [1, 487],
#  [3, 1, 707, 239, 13242, 604, 717, 5723, 68, 16539, 318, 26308],
#  [1, 186, 52],
#  [1, 102, 83],
#  [1, 287, 410],
#  [1, 2, 230, 5420, 19491, 988, 2246, 404, 210, 9692, 11425],
#  [1, 2067, 211, 1482, 2545, 204, 5242, 115, 89, 371],
#  [26309, 1, 356, 107, 517, 33, 1249, 5623],
#  [1, 6, 450, 4, 134, 175, 652, 3065, 232, 870, 540, 8, 14, 4, 47, 574, 450],
#  [135, 1, 10, 70, 290, 85, 1, 219, 660, 196],
#  [1, 1514, 243, 98, 988, 978, 115, 89, 13243, 690],
#  [4686, 3, 1, 26, 1173, 26, 405],
#  [1, 14, 34, 12, 3, 163],
#  [172, 1, 467],
#  [108, 79, 494, 148, 2781, 1, 998, 998, 7, 4489, 169, 8838],
#  [1011, 29, 110, 117, 1964, 463, 1, 61, 146, 4, 1, 56],
#  [131, 1, 485, 983, 1248],
#  [201, 2998, 1702, 326, 512, 1, 663, 710, 383, 828],
#  [172, 435, 1, 643, 456, 703, 175],
#  [1, 2, 19, 573, 1014, 55, 226],
#  [12, 36, 822, 95, 125, 108, 1, 356],
#  [1, 552, 39, 17, 1543, 862, 346, 122],
#  [145, 1, 59, 72, 15, 506],
#  [3, 29, 90, 226, 1207, 3, 1, 541],
#  [5, 661, 881, 1, 400, 471, 256, 278],
#  [12, 29, 1, 434, 15, 4945, 3535, 168],
#  [1, 2, 470, 62, 14, 4, 14, 5, 1145, 14, 2017, 918, 8, 422],
#  [727, 815, 718, 24, 386, 241, 2409, 32, 9, 1, 403, 3, 1837, 4088],
#  [4, 445, 820, 367, 90, 49, 69, 656, 1400, 613, 1, 474, 6805],
#  [10, 1, 1112, 63, 87, 5, 921, 3948, 49, 801, 812],
#  [99, 9, 4301, 1, 141, 434, 65, 12260, 206, 779],
#  [3,
#   1,
#   361,
#   1998,
#   480,
#   814,
#   4,
#   1998,
#   47,
#   1620,
#   1152,
#   2392,
#   60,
#   839,
#   1134,
#   303,
#   7910],
#  [1, 231, 56, 77, 1, 248, 5, 4, 532, 589, 96, 1303, 244],
#  [1, 1704, 356, 92, 386],
#  [1, 1386, 1217, 35, 551, 27, 287, 110],
#  [61, 1, 400, 283, 804, 820],
#  [892, 109, 7, 58, 1, 369, 1466, 454, 14, 111, 11, 165, 248, 194],
#  [1, 1196, 329, 902, 13244, 96, 1406, 10171, 4427],
#  [48, 598, 25, 1, 496],
#  [3667, 2302, 5, 413, 169, 1, 585, 338, 183, 187],
#  [1, 603, 5326, 3142, 6, 257, 34, 42, 455, 62, 994, 2181, 1375, 69, 1301],
#  [1, 360, 1115],
#  [246,
#   2,
#   9693,
#   1,
#   59,
#   848,
#   761,
#   12,
#   8,
#   130,
#   1280,
#   2,
#   3,
#   35,
#   1478,
#   742,
#   130,
#   2,
#   17,
#   1098,
#   1594,
#   3,
#   2546],
#  [1, 83, 93],
#  [132, 32, 293, 674, 6, 237, 1, 375, 1866, 511],
#  [180, 1, 791, 12261, 95],
#  [31, 1, 2, 836, 108, 20, 19, 2914, 847, 193, 769, 822],
#  [1, 466, 740],
#  [94, 76, 525, 59, 3507, 845, 64, 1, 13, 103],
#  [1, 256, 505, 136],
#  [1, 716, 93, 3692, 1556, 6319],
#  [10, 1, 675, 16540],
#  [1, 631, 13, 10749],
#  [54, 4, 142, 341, 1, 51, 59, 1, 15, 612, 164],
#  [224, 218, 5525, 1, 571, 1671],
#  [21, 1, 234, 443],
#  [1, 474, 382, 170, 4387],
#  [1, 2, 504, 568, 16, 51, 192, 88, 3693, 277],
#  [247,
#   19492,
#   6806,
#   8171,
#   187,
#   1,
#   253,
#   150,
#   953,
#   77,
#   3668,
#   40,
#   679,
#   556,
#   2075,
#   429,
#   94,
#   113,
#   5013,
#   196,
#   136,
#   429,
#   135,
#   126],
#  [3, 1, 572, 107, 110, 41, 348, 142, 3, 9, 178, 410],
#  [3,
#   73,
#   3,
#   516,
#   773,
#   309,
#   4,
#   62,
#   62,
#   14,
#   23,
#   878,
#   1,
#   6633,
#   67,
#   1171,
#   105,
#   468,
#   10750,
#   84,
#   8,
#   886],
#  [1, 2, 3, 121, 575, 28, 4, 1172, 16],
#  [1,
#   32,
#   509,
#   7,
#   646,
#   285,
#   107,
#   1559,
#   31,
#   201,
#   31,
#   3310,
#   164,
#   736,
#   318,
#   35,
#   95,
#   7429,
#   31],
#  [245, 1, 155, 6, 14, 2081, 1054, 56, 1860],
#  [1, 423, 266, 107, 71, 699, 1391],
#  [969, 105, 1688, 1114, 1, 1550, 11, 1550, 305, 378, 882, 111],
#  [1, 796, 3355, 115, 89, 4629],
#  [1, 163, 115, 89, 19493],
#  [1, 374],
#  [3, 19, 1, 135, 3457, 1920, 3669, 14639],
#  [413, 1, 2, 11426, 65, 7, 224, 658, 175, 1, 456, 121],
#  [1, 42, 252, 67],
#  [44, 592, 1092, 5, 84, 1046, 223, 9, 4018, 1, 543, 589],
#  [61, 795, 1, 15, 168, 244, 504],
#  [3, 1, 265, 395, 41],
#  [1, 68, 463],
#  [3, 167, 1406, 265, 851, 1, 2, 129, 22, 62, 7, 3, 155, 204, 288, 5, 305, 22],
#  [345, 1, 307],
#  [1, 61, 169, 547, 552, 354, 24],
#  [39, 27, 39, 406, 238, 8, 1, 558, 24, 39, 35, 93, 24, 39, 35, 238, 37],
#  [1, 102, 1424],
#  [1, 4, 62, 64, 2753, 61, 2753, 7215, 47, 1481, 14, 3484, 2728, 112, 37],
#  [1536, 689, 1983, 81, 67, 525, 67, 177, 689, 617, 1495, 1, 26, 481],
#  [289, 1, 88],
#  [1, 395, 1637, 694],
#  [1, 2, 3, 43, 4815, 44, 43, 894, 1338],
#  [4053, 4333, 1210, 13245, 1, 85, 1078, 832, 459, 4053],
#  [3, 3867, 3, 733, 219, 43, 847, 2065, 4, 638, 101, 1, 557],
#  [1, 2111, 107, 62, 139, 2111, 935, 93, 95, 21, 10],
#  [3, 1, 601, 77, 989, 552, 304],
#  [3, 85, 1, 593],
#  [224, 1, 2, 3, 25, 506],
#  [19, 1, 405, 12, 26, 529, 120, 104, 961, 1231, 17],
#  [4,
#   2149,
#   12,
#   107,
#   6807,
#   8839,
#   173,
#   568,
#   1488,
#   326,
#   1324,
#   2968,
#   252,
#   2,
#   173,
#   1623,
#   1,
#   166],
#  [1, 185, 672, 257, 15, 114, 94, 45, 1422],
#  [1, 26, 230, 32, 868, 834, 335, 695, 771, 331],
#  [1673, 1, 259],
#  [39, 1, 88, 26310],
#  [1, 26, 1072, 1861, 972],
#  [1, 2, 2874, 348, 835, 79, 193, 19494, 96],
#  [8, 2313, 1348, 1118, 835, 7661, 1742, 170, 1, 195, 2575],
#  [1, 340],
#  [427, 41, 1, 518, 46, 97, 57],
#  [1, 8, 1674, 11, 11427, 82],
#  [44,
#   91,
#   1,
#   397,
#   184,
#   137,
#   1443,
#   1709,
#   91,
#   10,
#   140,
#   30,
#   2760,
#   4254,
#   474,
#   342,
#   229,
#   877],
#  [163, 2410, 1, 11, 960, 2695],
#  [19, 1, 13, 128, 59, 244, 3, 1, 92, 910, 67, 412],
#  [1, 1250, 35, 462, 1247, 3205],
#  [4,
#   19,
#   1950,
#   1,
#   542,
#   182,
#   1840,
#   1965,
#   183,
#   182,
#   51,
#   753,
#   1560,
#   948,
#   51,
#   6,
#   82,
#   182,
#   183],
#  [1, 119, 504, 28, 4, 1619, 589, 57, 105, 445, 262, 2254],
#  [34,
#   189,
#   173,
#   455,
#   74,
#   119,
#   122,
#   182,
#   568,
#   119,
#   2656,
#   119,
#   24,
#   1,
#   1760,
#   150,
#   231],
#  [1, 76, 2057, 225, 472, 5624, 94, 22, 3721],
#  [3, 73, 1393, 175, 1057, 930, 1, 603, 616],
#  [289, 856, 426, 2147, 349, 1, 567, 4876],
#  [1689, 2527, 577, 1, 287, 410],
#  [28, 188, 48, 578, 1, 536, 426, 630, 2106, 2, 760],
#  [191, 314, 1, 263, 456, 2011, 719, 373, 173],
#  [2,
#   104,
#   208,
#   3016,
#   589,
#   355,
#   5327,
#   763,
#   7,
#   7,
#   1,
#   357,
#   29,
#   5,
#   339,
#   119,
#   708,
#   1627],
#  [1, 34, 566, 329, 53, 96, 41, 179, 26311, 753, 1669, 358, 329, 41, 672, 126],
#  [3, 1, 374, 136, 120, 113, 1312],
#  [1, 9694, 11, 117],
#  [1, 13, 297, 181, 67],
#  [1,
#   2,
#   61,
#   956,
#   2108,
#   19,
#   722,
#   520,
#   660,
#   261,
#   8,
#   199,
#   68,
#   843,
#   10172,
#   19,
#   586,
#   1,
#   2,
#   4,
#   92],
#  [70, 174, 234, 435, 560, 51, 40, 2019, 1, 595, 344, 266],
#  [1, 832, 262, 1110],
#  [1, 65, 61],
#  [44, 1, 1667, 406, 32, 626, 1607, 54, 66, 1585, 1414, 17, 153, 3949],
#  [3, 363, 697, 18, 1, 234],
#  [1, 479],
#  [1, 167, 914, 592, 2555],
#  [1, 1630, 37, 26312],
#  [761, 1, 301, 761, 719, 273, 1113, 1428, 900],
#  [34,
#   26313,
#   105,
#   412,
#   1,
#   421,
#   5,
#   1039,
#   196,
#   26,
#   4254,
#   2146,
#   220,
#   110,
#   100,
#   25,
#   2439,
#   67,
#   725],
#  [1, 407, 424],
#  [255, 1, 1067, 6, 142, 43, 2],
#  [1, 253, 225, 6991, 6320, 17, 54, 97],
#  [11, 31, 1, 361, 106, 115, 89, 19495],
#  [237, 1, 121, 297, 999, 778, 115, 89, 953],
#  [31, 62, 1, 88],
#  [1, 2977, 30],
#  [425,
#   1,
#   163,
#   234,
#   66,
#   17,
#   120,
#   19496,
#   172,
#   2952,
#   21,
#   232,
#   393,
#   1060,
#   10,
#   46,
#   2655],
#  [1, 683],
#  [1,
#   1729,
#   26314,
#   22,
#   3459,
#   26315,
#   859,
#   1375,
#   1920,
#   9695,
#   986,
#   856,
#   749,
#   97,
#   5087,
#   1642,
#   215],
#  [3, 1, 426, 1459],
#  [982, 1, 306, 3266, 540, 97, 347],
#  [1, 514, 106, 204, 738, 632, 743],
#  [172,
#   2272,
#   276,
#   16541,
#   3102,
#   1193,
#   2455,
#   130,
#   165,
#   23,
#   14,
#   8,
#   1,
#   616,
#   637,
#   281,
#   660],
#  [1, 156, 306, 3380, 4687, 916, 5014, 31, 225, 2597, 4255, 3402, 61],
#  [382, 3831, 62, 467, 1, 716, 136],
#  [592,
#   1559,
#   13246,
#   1559,
#   807,
#   964,
#   1,
#   28,
#   270,
#   564,
#   14,
#   28,
#   270,
#   450,
#   2999,
#   171,
#   7,
#   270,
#   222,
#   285,
#   20,
#   112,
#   102,
#   197],
#  [1, 321, 1045, 7, 1, 61, 297, 17, 1033, 442],
#  [1, 22, 407, 101],
#  [1, 593, 308],
#  [3,
#   1,
#   536,
#   511,
#   3,
#   9,
#   9,
#   997,
#   175,
#   96,
#   1038,
#   144,
#   30,
#   244,
#   9234,
#   335,
#   1010,
#   1043,
#   6634,
#   5088,
#   8,
#   17,
#   1120,
#   628,
#   105],
#  [227, 30, 9, 71, 105, 1, 663, 3],
#  [1, 2, 7430, 519, 2140, 1967, 26316, 413, 47, 616, 3381, 471, 8172],
#  [1, 163, 745, 530, 1200],
#  [808, 398, 3250, 1495, 48, 1, 320, 830, 1128, 58, 126, 1529],
#  [1, 498, 376, 24, 141],
#  [39,
#   1,
#   567,
#   732,
#   127,
#   159,
#   273,
#   1537,
#   7,
#   1219,
#   9696,
#   103,
#   3267,
#   1673,
#   108,
#   80,
#   84],
#  [3, 86, 892, 79, 55, 202, 86, 109, 1137, 607, 1, 1168, 96, 967, 389],
#  [1, 93, 4755, 599, 1491, 221, 76, 4127, 2707],
#  [232, 711, 1, 358, 245, 3159, 7216, 2655, 195, 32, 1336, 1258],
#  [1, 576, 116, 278, 167, 407, 437, 215, 31, 57],
#  [29, 1, 566],
#  [1, 88, 4, 267, 76, 1569, 240, 372, 1631, 760],
#  [1, 362, 196, 233, 370, 40, 88, 4424, 44],
#  [1,
#   2,
#   1296,
#   163,
#   1278,
#   6808,
#   96,
#   2042,
#   987,
#   3950,
#   73,
#   9,
#   114,
#   387,
#   1296,
#   163,
#   1278,
#   3638,
#   13247],
#  [1, 55, 121, 555, 1577, 122, 3179, 1281],
#  [33,
#   62,
#   1153,
#   882,
#   167,
#   127,
#   711,
#   76,
#   10,
#   20,
#   55,
#   1,
#   42,
#   298,
#   55,
#   2044,
#   1696],
#  [1, 492, 712],
#  [3, 17, 1, 130, 17, 354],
#  [1, 14640, 225, 722],
#  [58, 438, 175, 24, 1, 6321, 35, 283, 411, 1508, 251, 96, 5089, 30],
#  [15, 996, 53, 1, 1027, 786, 1029],
#  [1, 2, 3, 785, 1572, 55, 39, 293, 68, 815],
#  [5, 1050, 480, 123, 2696, 1768, 76, 1, 25, 813, 356, 1249],
#  [40, 1, 13, 26, 392],
#  [1, 263, 582, 35, 86, 268, 74, 190],
#  ...]

# %%
padded_sequences
# Out:
# array([[    0,     0,     0, ...,   213,  1257,   133],
#        [    0,     0,     0, ...,     6,    38,    16],
#        [    0,     0,     0, ..., 26262,     1,   998],
#        ...,
#        [    0,     0,     0, ...,     7,  1404,   354],
#        [    0,     0,     0, ..., 51531,   114,    31],
#        [    0,     0,     0, ...,     1,   507,    14]])

# %%
encoded_labels
# Out:
# array([4, 0, 4, ..., 5, 3, 5], dtype=int64)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, encoded_labels, test_size=0.2, random_state=42)

# %%
print(X_train)
print(X_test)
print(y_train)
print(y_test)
# Out:
# [[   0    0    0 ...  523 7223  972]
#  [   0    0    0 ...  284  714   11]
#  [   0    0    0 ...  278  265 5922]
#  ...
#  [   0    0    0 ...    0    1  631]
#  [   0    0    0 ...  265 4970  105]
#  [   0    0    0 ...    1  166  851]]
# [[    0     0     0 ...    15 28510   658]
#  [    0     0     0 ...  4636  2342   688]
#  [    0     0     0 ...   748  1012   105]
#  ...
#  [    0     0     0 ...     1   515  1768]
#  [    0     0     0 ...     1  1136   428]
#  [    0     0     0 ...  1064   142    16]]
# [0 1 3 ... 3 1 4]
# [0 0 3 ... 1 3 0]

# %%
# Define the LSTM model
embedding_dim = 100
vocab_size = len(tokenizer.word_index) + 1
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_shape=(max_sequence_length, )))
model.add(LSTM(units=128))
model.add(Dense(units=6, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:81: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 79, 100)        │     5,153,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,813,668 (60.32 MB)
#  Trainable params: 5,271,222 (20.11 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 10,542,446 (40.22 MB)

# %%
# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 874s 84ms/step - accuracy: 0.8553 - loss: 0.3510 - val_accuracy: 0.9232 - val_loss: 0.1443
# Epoch 2/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 885s 85ms/step - accuracy: 0.9259 - loss: 0.1345 - val_accuracy: 0.9233 - val_loss: 0.1384
# Epoch 3/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 889s 85ms/step - accuracy: 0.9311 - loss: 0.1208 - val_accuracy: 0.9210 - val_loss: 0.1393
# Epoch 4/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 885s 85ms/step - accuracy: 0.9362 - loss: 0.1097 - val_accuracy: 0.9169 - val_loss: 0.1458
# Epoch 5/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 913s 88ms/step - accuracy: 0.9373 - loss: 0.1046 - val_accuracy: 0.9114 - val_loss: 0.1501
# Epoch 6/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 925s 88ms/step - accuracy: 0.9411 - loss: 0.0976 - val_accuracy: 0.9106 - val_loss: 0.1576
# Epoch 7/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 905s 87ms/step - accuracy: 0.9425 - loss: 0.0929 - val_accuracy: 0.9075 - val_loss: 0.1699
# Epoch 8/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 915s 88ms/step - accuracy: 0.9444 - loss: 0.0902 - val_accuracy: 0.9070 - val_loss: 0.1828
# Epoch 9/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 910s 87ms/step - accuracy: 0.9451 - loss: 0.0868 - val_accuracy: 0.9035 - val_loss: 0.1990
# Epoch 10/10
# 10421/10421 ━━━━━━━━━━━━━━━━━━━━ 918s 88ms/step - accuracy: 0.9470 - loss: 0.0839 - val_accuracy: 0.9037 - val_loss: 0.2109

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")
# Out:
# 2606/2606 ━━━━━━━━━━━━━━━━━━━━ 54s 21ms/step - accuracy: 0.9036 - loss: 0.2076
# Test Loss: 0.21085695922374725, Test Accuracy: 0.9036731123924255

# %%
###evaluation

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
random_forest = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = random_forest.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Test Accuracy: {accuracy}")

print(classification_report(y_test, y_pred))
# Out:
# Test Accuracy: 0.4157409851011252
#               precision    recall  f1-score   support
#
#            0       0.46      0.50      0.48     24201
#            1       0.41      0.70      0.52     28164
#            2       0.19      0.06      0.10      6929
#            3       0.44      0.12      0.19     11441
#            4       0.32      0.09      0.15      9594
#            5       0.14      0.05      0.07      3033
#
#     accuracy                           0.42     83362
#    macro avg       0.33      0.25      0.25     83362
# weighted avg       0.39      0.42      0.37     83362
